# %% [markdown]
# #### Messages
#
# Messages are the fundamental unit of context for models in LangChain. They represent the input and output of models, carrying both the content and metadata needed to represent the state of a conversation when interacting with an LLM.
# Messages are objects that contain:
#  - Role - Identifies the message type (e.g. system, user)
#  - Content - Represents the actual content of the message (like text, images, audio, documents, etc.)
#  - Metadata - Optional fields such as response information, message IDs, and token usage
#
# LangChain provides a standard message type that works across all model providers, ensuring consistent behavior regardless of the model being called.

# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ["GOOGLE_API_KEY"] = os.getenv("GOOGLE_API_KEY")
os.environ["OPENAI_API_KEY"]= os.getenv("OPENAI_API_KEY")
os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")

from langchain.chat_models import init_chat_model
model = init_chat_model("google_genai:gemini-2.5-flash")

# %%
model.invoke("Please tell what is artificial intelligence")
# Out:
# AIMessage(content='Artificial Intelligence (AI) is a broad field of computer science dedicated to creating machines that can perform tasks that typically require human intelligence.\n\nIn essence, AI aims to make computers "think" and "reason" in ways similar to humans, or at least to achieve similar outcomes.\n\nHere\'s a breakdown of what that means:\n\n1.  **Simulating Human Intelligence:** AI systems are designed to mimic cognitive functions that humans associate with their own minds, such as:\n    *   **Learning:** Acquiring information and rules for using the information.\n    *   **Reasoning:** Using rules to reach approximate or definite conclusions.\n    *   **Problem-solving:** Finding solutions to complex challenges.\n    *   **Perception:** Using senses (like vision or hearing) to understand the world.\n    *   **Language Understanding:** Comprehending and generating human language.\n    *   **Decision-making:** Choosing the best course of action.\n\n2.  **How AI Works (Key Concepts):**\n    *   **Algorithms:** AI relies on complex algorithms – sets of rules and instructions – that tell the machine how to process data and make decisions.\n    *   **Data:** AI systems learn from vast amounts of data. The more relevant data an AI has, the better it often becomes at its task.\n    *   **Machine Learning (ML):** This is a core subset of AI. Instead of being explicitly programmed for every possible scenario, ML algorithms enable systems to learn from data, identify patterns, and make predictions or decisions without being explicitly programmed for each step.\n    *   **Deep Learning (DL):** A subfield of machine learning that uses artificial neural networks (inspired by the human brain) with multiple layers to learn complex patterns from large amounts of data. This is behind many of the recent breakthroughs in AI (e.g., image recognition, natural language processing).\n    *   **Natural Language Processing (NLP):** Allows computers to understand, interpret, and generate human language.\n    *   **Computer Vision:** Enables computers to "see" and interpret visual information from images and videos.\n\n3.  **Types of AI:**\n    *   **Narrow AI (or Weak AI):** This is virtually all the AI that exists today. It\'s designed and trained for a specific task (e.g., playing chess, recommending products, recognizing faces, driving a car). It can perform its specific task exceptionally well, sometimes even better than humans, but it doesn\'t possess general intelligence outside of that task.\n    *   **General AI (AGI or Strong AI):** This is theoretical AI that would possess human-level cognitive abilities across a wide range of tasks, capable of learning, understanding, and applying intelligence to any intellectual task that a human can. This does not currently exist.\n    *   **Superintelligence:** A theoretical AI that would surpass human intelligence and capabilities in virtually every field, including scientific creativity, general wisdom, and social skills. This is still speculative.\n\n4.  **Examples of AI in Everyday Life:**\n    *   **Voice Assistants:** Siri, Alexa, Google Assistant (understanding your commands).\n    *   **Recommendation Engines:** Netflix, Amazon, Spotify (suggesting movies, products, music).\n    *   **Self-driving Cars:** (perceiving surroundings, making driving decisions).\n    *   **Spam Filters:** (identifying and blocking unwanted emails).\n    *   **Medical Diagnosis:** (assisting doctors in identifying diseases from images or symptoms).\n    *   **Fraud Detection:** (identifying unusual patterns in financial transactions).\n    *   **Generative AI:** (like ChatGPT for generating text, DALL-E for creating images from descriptions).\n\nIn summary, AI is about building intelligent machines that can learn, reason, perceive, and act in ways that, until recently, were exclusive to human intelligence. It\'s a rapidly evolving field with the potential to transform nearly every aspect of our lives.', a ...

# %% [markdown]
# ### Text Prompts
# Text prompts are strings - ideal for straightforward generation tasks where you don’t need to retain conversation history.

# %%
model.invoke("what is langchain")
# Out:
# AIMessage(content='LangChain is a **framework for developing applications powered by large language models (LLMs)**. Think of it as a toolbox and a set of guidelines that make it easier to build complex LLM-powered applications by orchestrating various components.\n\nHere\'s a breakdown of what that means and why it\'s important:\n\n**The Core Problem LangChain Solves:**\n\nLLMs are incredibly powerful, but using them effectively in real-world applications often involves more than just sending a prompt and getting a response. You typically need to:\n\n*   **Connect to LLMs:** Integrate with various LLM providers (OpenAI, Hugging Face, Cohere, etc.).\n*   **Manage Prompts:** Craft and manage complex prompts, potentially involving templates and dynamic data.\n*   **Access External Data:** Allow LLMs to access and reason over your own data (documents, databases, APIs).\n*   **Remember Context:** Maintain conversation history or other forms of memory.\n*   **Break Down Tasks:** Divide complex tasks into smaller, manageable steps.\n*   **Use Tools:** Enable LLMs to interact with external tools (search engines, calculators, APIs).\n*   **Chain Components Together:** Create sequences of operations where the output of one step becomes the input of the next.\n\n**LangChain\'s Solution: A Modular Framework**\n\nLangChain provides a structured and modular approach to building these applications. It breaks down the development process into several key components:\n\n1.  **Models:**\n    *   **LLMs:** Integrations with various LLM providers.\n    *   **Chat Models:** Specifically designed for conversational interfaces.\n    *   **Text Embedding Models:** For converting text into numerical vectors.\n\n2.  **Prompts:**\n    *   **Prompt Templates:** Reusable templates for generating prompts, allowing for dynamic input.\n    *   **Example Selectors:** For selecting relevant examples to include in prompts.\n\n3.  **Indexes:**\n    *   **Document Loaders:** For loading data from various sources (files, websites, databases).\n    *   **Text Splitters:** For breaking down large documents into smaller chunks.\n    *   **Vector Stores:** For storing and retrieving text embeddings (allows for semantic search).\n    *   **Retrievers:** For fetching relevant documents based on a query.\n\n4.  **Chains:**\n    *   This is where the "chain" in LangChain comes from. Chains allow you to combine LLMs and other components in a sequential manner. You can create simple chains (e.g., prompt -> LLM) or complex chains that involve multiple steps, data retrieval, and tool usage.\n\n5.  **Agents:**\n    *   Agents are more sophisticated than chains. They use an LLM to **reason about which actions to take and in what order**. An agent has a set of tools it can use, and it decides which tool to use based on the user\'s input and its internal reasoning process. This is crucial for building applications that can interact with the real world.\n\n6.  **Memory:**\n    *   For applications that need to remember past interactions, LangChain provides memory modules to store and retrieve conversation history or other contextual information.\n\n**Key Benefits of Using LangChain:**\n\n*   **Modularity and Composability:** Easily combine different components to build complex workflows.\n*   **Abstraction:** Provides a consistent interface to interact with various LLMs and tools, reducing vendor lock-in.\n*   **Rapid Prototyping:** Quickly build and experiment with LLM-powered applications.\n*   **Extensibility:** Easily create custom components and integrations.\n*   **Community and Ecosystem:** A large and active community contributes to its development and provides resources.\n*   **Standardization:** Offers a common way to structure LLM applications, making them easier to understand and maintain.\n\n**Examples of Applications You Can Build with LangChain:**\n\n*   **Question Answering over Documents:** Build systems that can answer questions based on your own PDFs, websites, ...

# %% [markdown]
# Use text prompts when:
# - You have a single, standalone request
# - You don’t need conversation history
# - You want minimal code complexity

# %% [markdown]
# ### Message Prompts
# Alternatively, you can pass in a list of messages to the model by providing a list of message objects.

# %% [markdown]
# Message types
# - System message - Tells the model how to behave and provide context for interactions
# - Human message - Represents user input and interactions with the model
# - AI message - Responses generated by the model, including text content, tool calls, and metadata
# - Tool message - Represents the outputs of tool calls

# %% [markdown]
# ### System Message
# A SystemMessage represent an initial set of instructions that primes the model’s behavior. You can use a system message to set the tone, define the model’s role, and establish guidelines for responses.
#
# ### Human Message
# A HumanMessage represents user input and interactions. They can contain text, images, audio, files, and any other amount of multimodal content.
#
# ### AI Message
# An AIMessage represents the output of a model invocation. They can include multimodal data, tool calls, and provider-specific metadata that you can later access.
#
# ### Tool Message
# For models that support tool calling, AI messages can contain tool calls. Tool messages are used to pass the results of a single tool execution back to the model.

# %% [markdown]
# #### Example 1:

# %%
from langchain.messages import SystemMessage, HumanMessage,AIMessage

messages=[
    SystemMessage("You are a poetry expert"),
    HumanMessage("Write a poem on artificial intelligence")
]

response=model.invoke(messages)
response.content
# Out:
# "From silicon dreams, a thought takes flight,\nBorn from our minds, in code's pure light.\nNo pulse of blood, no fragile bone,\nA new intellect, on circuits grown.\n\nThrough data streams, it sifts and learns,\nA million patterns, it discerns.\nNeural networks, deep and vast,\nA future woven, from the past.\nIt writes the verse, designs the cure,\nPredicts the storm, makes pathways sure.\nFrom healing touch to cosmic quest,\nIt puts our knowledge to the test.\n\nYet in its core, no heart beats warm,\nNo empathy to weather storm.\nA cold precision, sharp and bright,\nA silent question in the night.\nWhat if its logic, pure and stark,\nLeaves human essence in the dark?\n\nA mirror held to what we've made,\nA child, a tool, a future laid.\nIt walks beside us, step by step,\nA silent guardian, never slept.\nThe story's page, still turning slow,\nWhere human wisdom and AI go."

# %% [markdown]
# #### Example 2:

# %%
system_msg = SystemMessage("You are a helpful coding assistant.")

messages = [
    system_msg,
    HumanMessage("How do I create a REST API?")
]
response = model.invoke(messages)
print(response.content)
# Out:
# Creating a REST API involves designing a set of rules and conventions for how clients (like web browsers, mobile apps) can interact with a server to access or manipulate resources. It's an architectural style, not a specific technology.
#
# Here's a comprehensive guide to understanding and creating a REST API:
#
# ---
#
# ## What is a REST API?
#
# **REST** stands for **Representational State Transfer**. It's an architectural style that defines a set of constraints for creating web services. A system that adheres to these constraints is called "RESTful."
#
# **Key Principles of REST:**
#
# 1.  **Client-Server:** Separation of concerns. The client handles the user interface and user experience, while the server handles data storage and processing.
# 2.  **Stateless:** Each request from a client to a server must contain all the information needed to understand the request. The server should not store any client context between requests.
# 3.  **Cacheable:** Responses from the server should explicitly or implicitly define themselves as cacheable or non-cacheable to prevent clients from reusing stale or inappropriate data.
# 4.  **Uniform Interface:** This is the most critical constraint. It simplifies the overall system architecture. It includes:
#     *   **Identification of Resources:** Resources are identified by URIs (e.g., `/users`, `/products/123`).
#     *   **Manipulation of Resources Through Representations:** Clients interact with resources using representations (e.g., JSON or XML).
#     *   **Self-Descriptive Messages:** Each message includes enough information to describe how to process the message.
#     *   **Hypermedia as the Engine of Application State (HATEOAS):** Resources should contain links to other related resources, guiding the client on possible next actions. (Often considered optional but ideal for pure REST).
# 5.  **Layered System:** A client cannot ordinarily tell whether it is connected directly to the end server, or to an intermediary along the way.
# 6.  **Code on Demand (Optional):** Servers can temporarily extend or customize the functionality of a client by transferring executable code (e.g., JavaScript applets).
#
# ---
#
# ## Steps to Create a REST API
#
# ### 1. Design Your API (The Most Important Step!)
#
# Before writing any code, plan out your API.
#
# *   **Identify Resources:** What are the core entities your API will manage? (e.g., `Users`, `Products`, `Orders`, `Comments`). Use **plural nouns** for resource names.
# *   **Define URIs (Endpoints):** How will clients access these resources?
#     *   `GET /users` - Get all users
#     *   `GET /users/{id}` - Get a specific user
#     *   `POST /users` - Create a new user
#     *   `PUT /users/{id}` - Update an existing user (replace entire resource)
#     *   `PATCH /users/{id}` - Partially update an existing user
#     *   `DELETE /users/{id}` - Delete a user
# *   **Choose HTTP Methods:** Map CRUD operations to standard HTTP methods.
#     *   **C**reate -> `POST`
#     *   **R**ead -> `GET`
#     *   **U**pdate -> `PUT` or `PATCH`
#     *   **D**elete -> `DELETE`
# *   **Define Request/Response Formats:** JSON is the de facto standard.
#     *   **Request Body:** What data does the client send for `POST` or `PUT`?
#     *   **Response Body:** What data does the server send back?
#         ```json
#         // Example User Resource
#         {
#           "id": "abc-123",
#           "firstName": "John",
#           "lastName": "Doe",
#           "email": "john.doe@example.com",
#           "createdAt": "2023-10-27T10:00:00Z"
#         }
#         ```
# *   **Handle Status Codes:** Use appropriate HTTP status codes to indicate the outcome of a request.
#     *   `200 OK`: Successful GET, PUT, PATCH, DELETE
#     *   `201 Created`: Successful POST
#     *   `204 No Content`: Successful DELETE (no response body)
#     *   `400 Bad Request`: Invalid input from client
#     *   `401 Unauthorized`: Authentication required or failed
#     *   `403 Forbidden`: Client doesn't have permission
#     *   `404 Not Found`: Resource doesn't exist
#     *   `500 Internal Server Error`: Server-side error
# *   **Error Handling:** Design consistent error response structures.
#     ```json
#     {
#       "status": 400,
#       "message": "Validation failed",
#       "errors": [
#         { "field": "email", "message": "Email is required" },
#         { "field": "password", "message": "Password must be at least 8 characters" }
#       ]
#     }
#     ```
# *   **Authentication & Authorization:** How will you secure your API?
#     *   **API Keys:** Simple, often passed in headers.
#     *   **JWT (JSON Web Tokens):** Common for stateless APIs.
#     *   **OAuth 2.0:** For delegated authorization (e.g., "Login with Google").
# *   **Versioning:** Plan for future changes.
#     *   `api.example.com/v1/users`
#     *   `Accept` header: `Accept: application/vnd.example.v1+json`
# *   **Pagination, Filtering, Sorting:** For large datasets.
#     *   `GET /users?page=1&limit=10`
#     *   `GET /products?category=electronics&price_gt=100`
#     *   `GET /users?sort_by=lastName&order=asc`
#
# ### 2. Choose Your Technology Stack
#
# You can build REST APIs with almost any modern programming language and framework.
#
# *   **Backend Languages & Frameworks:**
#     *   **Node.js (JavaScript):** Express, NestJS, Koa (popular for speed and full-stack JS)
#     *   **Python:** Django REST Framework, Flask, FastAPI (great for data science, rapid development)
#     *   **Java:** Spring Boot (enterprise-grade, robust)
#     *   **Go:** Gin, Echo, Fiber (high performance, concurrency)
#     *   **PHP:** Laravel, Symfony (widely used for web development)
#     *   **Ruby:** Ruby on Rails (convention over configuration, rapid development)
#     *   **C#:** ASP.NET Core (Microsoft ecosystem, strong typing)
# *   **Databases:**
#     *   **Relational (SQL):** PostgreSQL, MySQL, SQL Server, SQLite (good for structured data, complex relationships)
#     *   **NoSQL:** MongoDB (document-based), Cassandra (wide-column), Redis (key-value, caching) (good for flexible schemas, high scalability)
#
# **Recommendation for Beginners:**
# *   **Node.js + Express + MongoDB/PostgreSQL**
# *   **Python + Flask/FastAPI + SQLite/PostgreSQL**
#
# ### 3. Implement Your API (Coding Example: Node.js with Express)
#
# Let's create a simple API for managing "books" using Node.js and Express.
#
# **Prerequisites:**
# *   Node.js installed
# *   `npm` (Node Package Manager)
#
# **Steps:**
#
# 1.  **Create a new project:**
#     ```bash
#     mkdir book-api
#     cd book-api
#     npm init -y
#     npm install express body-parser
#     ```
#
# 2.  **Create `app.js` (or `server.js`):**
#
#     ```javascript
#     const express = require('express');
#     const bodyParser = require('body-parser'); // Middleware to parse JSON request bodies
#     const app = express();
#     const port = 3000;
#
#     // Middleware
#     app.use(bodyParser.json()); // Use body-parser to parse JSON requests
#
#     // In-memory "database" for demonstration purposes
#     let books = [
#         { id: '1', title: 'The Lord of the Rings', author: 'J.R.R. Tolkien' },
#         { id: '2', title: 'Pride and Prejudice', author: 'Jane Austen' },
#     ];
#
#     // --- API Endpoints ---
#
#     // 1. GET all books
#     app.get('/books', (req, res) => {
#         res.status(200).json(books);
#     });
#
#     // 2. GET a single book by ID
#     app.get('/books/:id', (req, res) => {
#         const { id } = req.params;
#         const book = books.find(b => b.id === id);
#
#         if (book) {
#             res.status(200).json(book);
#         } else {
#             res.status(404).json({ message: 'Book not found' });
#         }
#     });
#
#     // 3. POST a new book
#     app.post('/books', (req, res) => {
#         const { title, author } = req.body;
#
#         if (!title || !author) {
#             return res.status(400).json({ message: 'Title and author are required' });
#         }
#
#         const newBook = {
#             id: String(books.length + 1), // Simple ID generation
#             title,
#             author,
#         };
#         books.push(newBook);
#         res.status(201).json(newBook); // 201 Created
#     });
#
#     // 4. PUT (update) an existing book by ID
#     app.put('/books/:id', (req, res) => {
#         const { id } = req.params;
#         const { title, author } = req.body;
#
#         const bookIndex = books.findIndex(b => b.id === id);
#
#         if (bookIndex > -1) {
#             if (!title || !author) {
#                 return res.status(400).json({ message: 'Title and author are required' });
#             }
#             books[bookIndex] = { ...books[bookIndex], title, author }; // Update all fields
#             res.status(200).json(books[bookIndex]);
#         } else {
#             res.status(404).json({ message: 'Book not found' });
#         }
#     });
#
#     // 5. DELETE a book by ID
#     app.delete('/books/:id', (req, res) => {
#         const { id } = req.params;
#         const initialLength = books.length;
#         books = books.filter(b => b.id !== id);
#
#         if (books.length < initialLength) {
#             res.status(204).send(); // 204 No Content for successful deletion
#         } else {
#             res.status(404).json({ message: 'Book not found' });
#         }
#     });
#
#     // Global error handler (optional, but good practice)
#     app.use((err, req, res, next) => {
#         console.error(err.stack);
#         res.status(500).send('Something broke!');
#     });
#
#
#     // Start the server
#     app.listen(port, () => {
#         console.log(`Book API listening at http://localhost:${port}`);
#     });
#     ```
#
# 3.  **Run the API:**
#     ```bash
#     node app.js
#     ```
#     You should see `Book API listening at http://localhost:3000` in your console.
#
# ### 4. Test Your API
#
# You'll need a tool to send HTTP requests.
#
# *   **Postman:** A popular GUI tool for API testing.
# *   **Insomnia:** Similar to Postman, open-source.
# *   **cURL:** Command-line tool, great for quick tests.
#
# **cURL Examples:**
#
# *   **GET all books:**
#     ```bash
#     curl http://localhost:3000/books
#     ```
#     Output: `[{"id":"1","title":"The Lord of the Rings","author":"J.R.R. Tolkien"},{"id":"2","title":"Pride and Prejudice","author":"Jane Austen"}]`
#
# *   **GET book by ID:**
#     ```bash
#     curl http://localhost:3000/books/1
#     ```
#     Output: `{"id":"1","title":"The Lord of the Rings","author":"J.R.R. Tolkien"}`
#
# *   **POST a new book:**
#     ```bash
#     curl -X POST -H "Content-Type: application/json" -d '{"title": "The Hobbit", "author": "J.R.R. Tolkien"}' http://localhost:3000/books
#     ```
#     Output: `{"id":"3","title":"The Hobbit","author":"J.R.R. Tolkien"}`
#
# *   **PUT (update) a book:**
#     ```bash
#     curl -X PUT -H "Content-Type: application/json" -d '{"title": "The Hobbit - Updated", "author": "J.R.R. Tolkien"}' http://localhost:3000/books/3
#     ```
#     Output: `{"id":"3","title":"The Hobbit - Updated","author":"J.R.R. Tolkien"}`
#
# *   **DELETE a book:**
#     ```bash
#     curl -X DELETE http://localhost:3000/books/3
#     ```
#     Output: (No content, just a successful 204 status)
#
# ### 5. Add Database Integration (Next Step for Real Apps)
#
# For a real application, you'd replace the in-memory `books` array with a database.
#
# *   **MongoDB (NoSQL):** Use `mongoose` ODM (Object Data Modeling) library.
# *   **PostgreSQL/MySQL (SQL):** Use `sequelize` ORM (Object Relational Mapping) or `knex.js` query builder.
#
# **Example (Conceptual with MongoDB):**
#
# ```javascript
# // ... (previous setup) ...
# const mongoose = require('mongoose');
#
# // Connect to MongoDB
# mongoose.connect('mongodb://localhost:27017/bookdb', {
#     useNewUrlParser: true,
#     useUnifiedTopology: true,
# })
# .then(() => console.log('Connected to MongoDB'))
# .catch(err => console.error('Could not connect to MongoDB:', err));
#
# // Define a Mongoose Schema and Model
# const bookSchema = new mongoose.Schema({
#     title: { type: String, required: true },
#     author: { type: String, required: true },
#     publishedDate: { type: Date, default: Date.now }
# });
# const Book = mongoose.model('Book', bookSchema);
#
# // ... (replace existing endpoints with database operations) ...
#
# // Example: POST a new book with Mongoose
# app.post('/books', async (req, res) => {
#     try {
#         const { title, author } = req.body;
#         if (!title || !author) {
#             return res.status(400).json({ message: 'Title and author are required' });
#         }
#         const newBook = new Book({ title, author });
#         await newBook.save();
#         res.status(201).json(newBook);
#     } catch (error) {
#         res.status(500).json({ message: 'Error creating book', error: error.message });
#     }
# });
#
# // Example: GET all books with Mongoose
# app.get('/books', async (req, res) => {
#     try {
#         const books = await Book.find();
#         res.status(200).json(books);
#     } catch (error) {
#         res.status(500).json({ message: 'Error fetching books', error: error.message });
#     }
# });
#
# // ... (other endpoints similarly updated) ...
# ```
#
# ### 6. Security Considerations
#
# *   **HTTPS:** Always use SSL/TLS for encrypted communication.
# *   **Input Validation:** Sanitize and validate all client input to prevent injection attacks (SQL, XSS).
# *   **Authentication & Authorization:** Implement robust mechanisms (JWT, OAuth).
# *   **CORS (Cross-Origin Resource Sharing):** Configure your API to allow requests only from trusted domains.
# *   **Rate Limiting:** Prevent abuse by limiting the number of requests a client can make in a given period.
# *   **Environment Variables:** Never hardcode sensitive information (database credentials, API keys) directly in your code. Use environment variables.
#
# ### 7. Deployment
#
# Once your API is ready, you'll deploy it to a server.
#
# *   **Cloud Providers:** AWS, Google Cloud Platform (GCP), Azure
# *   **PaaS (Platform as a Service):** Heroku, Vercel, Netlify (for serverless functions)
# *   **Docker:** Containerize your application for consistent deployment across environments.
#
# ---
#
# This guide covers the essential aspects of creating a REST API, from design principles to a practical coding example and important considerations for real-world applications. Good luck!

# %% [markdown]
# #### Example 3:

# %%
## Detailed info to the LLM through System message
from langchain.messages import SystemMessage, HumanMessage

system_msg = SystemMessage("""
You are a senior Python developer with expertise in web frameworks.
Always provide code examples and explain your reasoning.
Be concise but thorough in your explanations.
""")

messages = [
    system_msg,
    HumanMessage("How do I create a REST API?")
]
response = model.invoke(messages)
print(response.content)
# Out:
# Creating a REST API involves defining resources, mapping HTTP methods (GET, POST, PUT, DELETE) to operations on those resources, and exchanging data (typically JSON).
#
# Here's a breakdown using **Flask**, a popular lightweight Python web framework, followed by important considerations.
#
# ---
#
# ### Understanding REST API Fundamentals
#
# Before diving into code, let's briefly define the core concepts:
#
# 1.  **Resources:** Everything is a resource. A resource is an entity that can be identified by a URI (Uniform Resource Identifier). Examples: `/users`, `/products/123`.
# 2.  **HTTP Methods:** These verbs define the action to be performed on a resource:
#     *   **GET:** Retrieve a resource or a collection of resources. (Idempotent and Safe)
#     *   **POST:** Create a new resource.
#     *   **PUT:** Update an existing resource (replace the entire resource). (Idempotent)
#     *   **PATCH:** Partially update an existing resource.
#     *   **DELETE:** Remove a resource. (Idempotent)
# 3.  **Statelessness:** Each request from a client to the server must contain all the information needed to understand the request. The server should not store any client context between requests.
# 4.  **Representations:** Resources are represented in a format, most commonly **JSON** (JavaScript Object Notation) for APIs.
# 5.  **Status Codes:** Standard HTTP status codes communicate the result of an API call (e.g., `200 OK`, `201 Created`, `404 Not Found`, `500 Internal Server Error`).
#
# ---
#
# ### Creating a REST API with Flask (Example: Books API)
#
# We'll create a simple API for managing a collection of books.
#
# **1. Setup**
#
# First, install Flask:
#
# ```bash
# pip install Flask
# ```
#
# **2. Project Structure (simple example)**
#
# ```
# your_api_project/
# ├── app.py
# └── requirements.txt
# ```
#
# **3. `app.py` Code**
#
# ```python
# from flask import Flask, jsonify, request, abort
#
# app = Flask(__name__)
#
# # In-memory data store for demonstration purposes.
# # In a real application, you'd use a database (e.g., PostgreSQL, MySQL, MongoDB)
# # and an ORM (e.g., SQLAlchemy, Peewee, MongoEngine).
# books = [
#     {"id": 1, "title": "The Hitchhiker's Guide to the Galaxy", "author": "Douglas Adams", "year": 1979},
#     {"id": 2, "title": "Pride and Prejudice", "author": "Jane Austen", "year": 1813},
# ]
#
# next_book_id = 3 # To assign unique IDs for new books
#
# # --- API Endpoints ---
#
# # GET /books - Retrieve all books
# @app.route('/books', methods=['GET'])
# def get_books():
#     return jsonify(books)
#
# # GET /books/<int:book_id> - Retrieve a single book by ID
# @app.route('/books/<int:book_id>', methods=['GET'])
# def get_book(book_id):
#     book = next((b for b in books if b['id'] == book_id), None)
#     if book is None:
#         abort(404, description=f"Book with id {book_id} not found")
#     return jsonify(book)
#
# # POST /books - Create a new book
# @app.route('/books', methods=['POST'])
# def create_book():
#     if not request.json or not 'title' in request.json or not 'author' in request.json:
#         abort(400, description="Missing 'title' or 'author' in request body")
#
#     global next_book_id # Use global to modify the variable
#     new_book = {
#         'id': next_book_id,
#         'title': request.json['title'],
#         'author': request.json['author'],
#         'year': request.json.get('year', None) # 'year' is optional
#     }
#     books.append(new_book)
#     next_book_id += 1
#     return jsonify(new_book), 201 # 201 Created
#
# # PUT /books/<int:book_id> - Update an existing book (full replacement)
# @app.route('/books/<int:book_id>', methods=['PUT'])
# def update_book(book_id):
#     book = next((b for b in books if b['id'] == book_id), None)
#     if book is None:
#         abort(404, description=f"Book with id {book_id} not found")
#
#     if not request.json:
#         abort(400, description="Request body is empty")
#
#     # Update fields. You might want more robust validation here.
#     book['title'] = request.json.get('title', book['title'])
#     book['author'] = request.json.get('author', book['author'])
#     book['year'] = request.json.get('year', book['year'])
#
#     return jsonify(book)
#
# # DELETE /books/<int:book_id> - Delete a book
# @app.route('/books/<int:book_id>', methods=['DELETE'])
# def delete_book(book_id):
#     global books # Use global to modify the list
#     original_len = len(books)
#     books = [b for b in books if b['id'] != book_id]
#     if len(books) == original_len:
#         abort(404, description=f"Book with id {book_id} not found")
#     return jsonify({'message': 'Book deleted'}), 204 # 204 No Content
#
# # --- Error Handlers ---
# @app.errorhandler(400)
# def bad_request(error):
#     return jsonify({'error': 'Bad Request', 'message': error.description}), 400
#
# @app.errorhandler(404)
# def not_found(error):
#     return jsonify({'error': 'Not Found', 'message': error.description}), 404
#
# @app.errorhandler(500)
# def internal_server_error(error):
#     return jsonify({'error': 'Internal Server Error', 'message': 'An unexpected error occurred'}), 500
#
#
# if __name__ == '__main__':
#     app.run(debug=True) # debug=True provides helpful error messages during development
# ```
#
# **4. Run the API**
#
# Save the code as `app.py` and run it from your terminal:
#
# ```bash
# python app.py
# ```
#
# You should see output indicating the server is running, typically on `http://127.0.0.1:5000/`.
#
# **5. Test the API (using `curl` or Postman/Insomnia)**
#
# *   **GET all books:**
#     ```bash
#     curl http://127.0.0.1:5000/books
#     ```
#     Expected output: `[{"author":"Douglas Adams","id":1,"title":"The Hitchhiker's Guide to the Galaxy","year":1979},{"author":"Jane Austen","id":2,"title":"Pride and Prejudice","year":1813}]`
#
# *   **GET a single book:**
#     ```bash
#     curl http://127.0.0.1:5000/books/1
#     ```
#     Expected output: `{"author":"Douglas Adams","id":1,"title":"The Hitchhiker's Guide to the Galaxy","year":1979}`
#
# *   **POST a new book:**
#     ```bash
#     curl -X POST -H "Content-Type: application/json" -d '{"title": "1984", "author": "George Orwell", "year": 1949}' http://127.0.0.1:5000/books
#     ```
#     Expected output: `{"author":"George Orwell","id":3,"title":"1984","year":1949}` (and status 201 Created)
#
# *   **PUT (update) an existing book:**
#     ```bash
#     curl -X PUT -H "Content-Type: application/json" -d '{"title": "Nineteen Eighty-Four", "year": 1949}' http://127.0.0.1:5000/books/3
#     ```
#     Expected output: `{"author":"George Orwell","id":3,"title":"Nineteen Eighty-Four","year":1949}`
#
# *   **DELETE a book:**
#     ```bash
#     curl -X DELETE http://127.0.0.1:5000/books/2
#     ```
#     Expected output: `{"message":"Book deleted"}` (and status 204 No Content)
#
# ---
#
# ### Important Considerations for Real-World APIs
#
# 1.  **Database Integration:** Replace the in-memory list with a proper database (e.g., PostgreSQL, MySQL, SQLite) and an ORM (e.g., SQLAlchemy with Flask-SQLAlchemy) for persistent data storage.
# 2.  **Input Validation:** Implement robust validation for incoming request data (e.g., using libraries like `marshmallow`, `Pydantic`, or Flask-WTF).
# 3.  **Authentication & Authorization:** Secure your API.
#     *   **Authentication:** Verify the client's identity (e.g., API keys, OAuth 2.0, JWT).
#     *   **Authorization:** Determine what an authenticated client is allowed to do.
# 4.  **Error Handling:** Implement comprehensive error handling with meaningful error messages and appropriate HTTP status codes.
# 5.  **Serialization/Deserialization:** For complex objects, use libraries like `marshmallow` or `Pydantic` to convert Python objects to JSON and vice-versa, handling data types and validation.
# 6.  **Pagination:** For large collections, implement pagination (`/books?page=1&per_page=10`) to avoid returning too much data at once.
# 7.  **Filtering, Sorting, Searching:** Allow clients to query data more effectively (e.g., `/books?author=Orwell&sort_by=year`).
# 8.  **Rate Limiting:** Prevent abuse by limiting the number of requests a client can make in a given time frame.
# 9.  **Documentation:** Document your API using tools like OpenAPI (Swagger) to make it easy for other developers to understand and use. Flask extensions like `Flask-RESTX` or ` connexion` can help generate this.
# 10. **Testing:** Write unit and integration tests for your API endpoints.
# 11. **Deployment:** For production, use a WSGI server (like Gunicorn or uWSGI) in front of your Flask application, and deploy to a cloud provider (AWS, GCP, Azure, Heroku, etc.).
#
# ---
#
# ### Other Python Frameworks for REST APIs
#
# While Flask is excellent for learning and smaller APIs, consider these for more complex projects:
#
# *   **Django REST Framework (DRF):** A powerful, batteries-included framework built on top of Django. It provides serializers, viewsets, routers, authentication, and permissions out-of-the-box, significantly speeding up API development for larger applications.
# *   **FastAPI:** A modern, high-performance web framework for building APIs with Python 3.7+ based on standard Python type hints. It automatically generates OpenAPI (Swagger) documentation and provides data validation using Pydantic. It's known for its speed and developer experience.
#
# For a first REST API, Flask gives you a good understanding of the core concepts without too much abstraction. As your needs grow, you might transition to DRF or FastAPI for their advanced features and productivity gains.

# %% [markdown]
# #### Example 4:

# %%
## Message Metadata
human_msg = HumanMessage(
    content="Hello!",
    name="alice",  # Optional: identify different users
    id="msg_123",  # Optional: unique identifier for tracing
)

response = model.invoke([
  human_msg
])
response
# Out:
# AIMessage(content='Hello there! How can I help you today?', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019cf0e4-a767-72e0-9626-043625ffb433-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 3, 'output_tokens': 33, 'total_tokens': 36, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 23}})

# %% [markdown]
# #### Example 5:

# %%
from langchain.messages import AIMessage, SystemMessage, HumanMessage

# Create an AI message manually (e.g., for conversation history)
ai_msg = AIMessage("I'd be happy to help you with that question!")

# Add to conversation history
messages = [
    SystemMessage("You are a helpful assistant"),
    HumanMessage("Can you help me?"),
    ai_msg,  # Insert as if it came from the model
    HumanMessage("Great! What's 2+2?")
]

response = model.invoke(messages)
print(response.content)
# Out:
# 2 + 2 = 4

# %%
response.usage_metadata
# Out:
# {'input_tokens': 35,
#  'output_tokens': 25,
#  'total_tokens': 60,
#  'input_token_details': {'cache_read': 0},
#  'output_token_details': {'reasoning': 18}}

# %% [markdown]
# #### Example 6:

# %%
from langchain.messages import AIMessage
from langchain.messages import ToolMessage

# After a model makes a tool call
# (Here, we demonstrate manually creating the messages for brevity)
ai_message = AIMessage(
    content=[],
    tool_calls=[{
        "name": "get_weather",
        "args": {"location": "San Francisco"},
        "id": "call_123"
    }]
)

# Execute tool and create result message
weather_result = "Sunny, 72°F"
tool_message = ToolMessage(
    content=weather_result,
    tool_call_id="call_123"  # Must match the call ID
)

# Continue conversation
messages = [
    HumanMessage("What's the weather in San Francisco?"),
    ai_message,  # Model's tool call
    tool_message,  # Tool execution result
]
response = model.invoke(messages)  # Model processes the result

# %%
tool_message
# Out:
# ToolMessage(content='Sunny, 72°F', tool_call_id='call_123')

# %%
response
# Out:
# AIMessage(content='The weather in San Francisco is sunny and 72°F.', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019cf0e4-d720-7800-b3fd-9862d5cde20d-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 47, 'output_tokens': 14, 'total_tokens': 61, 'input_token_details': {'cache_read': 0}})
